# %% [markdown]
# <a href="https://colab.research.google.com/github/mustaphatafzi-net/react-tasks/blob/main/TP1_DataMining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("heart.csv", sep=";")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  target
# 0  0.0   6.0       0
# 1  3.0   3.0       1
# 2  2.0   7.0       1
# 3  0.0   3.0       0
# 4  0.0   3.0       0

# %%
df.shape
# Out:
# (245, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       245 non-null    int64
#  1   sex       245 non-null    int64
#  2   cp        245 non-null    int64
#  3   trestbps  245 non-null    int64
#  4   chol      245 non-null    int64
#  5   fbs       245 non-null    int64
#  6   restecg   245 non-null    int64
#  7   thalach   245 non-null    int64
#  8   exang     245 non-null    int64
#  9   oldpeak   245 non-null    float64
#  10  slope     245 non-null    int64
#  11  ca        244 non-null    float64
#  12  thal      243 non-null    float64
#  13  target    245 non-null    int64
# dtypes: float64(3), int64(11)
# memory usage: 26.9 KB

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca          float64
# thal        float64
# target        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          1
# thal        2
# target      0
# dtype: int64

# %%
df['ca'].fillna(df['ca'].median(), inplace=True)
df['thal'].fillna(df['thal'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_14031/1200089458.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ca'].fillna(df['ca'].median(), inplace=True)
# /tmp/ipykernel_14031/1200089458.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(30)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    56.134884    0.641860    3.162791  131.953488  253.218605    0.162791
# std      8.533904    0.480572    0.846384   17.138187   56.951394    0.370036
# min     34.000000    0.000000    1.000000   94.000000  123.000000    0.000000
# 25%     51.000000    0.000000    3.000000  120.000000  217.500000    0.000000
# 50%     57.000000    1.000000    3.000000  130.000000  246.000000    0.000000
# 75%     62.000000    1.000000    4.000000  140.000000  282.500000    0.000000
# max     79.000000    1.000000    4.000000  192.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean     1.013953  148.534884    0.279070    1.017674    1.572093    0.655814
# ...

# %%
corr = df.corr()
corr
# Out:
#                age       sex        cp  trestbps      chol           fbs  \
# age       1.000000 -0.131732  0.141863  0.281780  0.259987  7.144194e-02
# sex      -0.131732  1.000000  0.132517 -0.046286 -0.254936  1.405538e-02
# cp        0.141863  0.132517  1.000000  0.050779  0.038035 -4.024984e-02
# trestbps  0.281780 -0.046286  0.050779  1.000000  0.112414  1.714111e-01
# chol      0.259987 -0.254936  0.038035  0.112414  1.000000  1.715108e-02
# fbs       0.071442  0.014055 -0.040250  0.171411  0.017151  1.000000e+00
# restecg   0.140190  0.000722  0.035871  0.075124  0.199130 -4.395364e-02
# thalach  -0.400043 -0.044931 -0.238902 -0.112918  0.038025  5.280481e-02
# exang     0.113154  0.161957  0.211618  0.161799  0.071154 -2.155620e-02
# oldpeak   0.167622  0.140110  0.200773  0.135969  0.072827 -3.099346e-02
# slope     0.176099  0.064174  0.143701  0.116255 -0.016961  4.066719e-02
# ca        0.350699  0.015044  0.205589  0.033112  0.163011  2.669766e-02
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
sns.histplot(df['age'], kde=True)
plt.title("Distribution de l'âge")
plt.show()

# %%
sns.countplot(x='sex', data=df)
plt.title("Répartition par sexe")
plt.show()

# %%
sns.boxplot(x='target', y='chol', data=df)
plt.title("Cholestérol selon la maladie")
plt.show()

# %%
sns.scatterplot(x='age', y='thalach', hue='target', data=df)
plt.title("Relation âge vs fréquence cardiaque")
plt.show()
